# %% [markdown]
# ### Data Cleaning - Problemas comunes:
#
# - Reading the file (Leyendo un archivo).<br>
# -Inconsistent column names (Nombre de columnas inconsistentes).<br>
# -Missing data (Datos perdidos).<br>
# -Different types of data (Diferentes tipos de datos).<br>
# -Duplicate rows (Filas duplicadas)

# %%
# Importamos Pnadas y Numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ### Cargar o Leer el archivo
# - Error de codificación.
# - Filas inconsistentes

# %%
# Intentamos cargar un archivo
data=pd.read_csv('D:/dirty data/unclean_data.csv') # leer el archivo csv

#ERROR: Podemos observar que nos arroja un problema de codificación, ya que no puede decodificar correctamente
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In [9], line 2
#       1 # Intentamos cargar un archivo
# ----> 2 data=pd.read_csv('D:/dirty data/unclean_data.csv')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
# SOLUCIÓN 1 - Codificación UTF

data=pd.read_csv('D:/dirty data/unclean_data.csv', encoding='latin1') #Codificamos la data en "latin1", permitirá leerlo
#Mostramos losprimeros 5 registros
data.head(5)
# NOTA: Ponerlo en latin no puede ser efectivo todo el tiempo
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
# SOLUCIÓN 2 - Crear una copia del file, usar el editor de texto(sublime text) y guardarlo como UTF-8, ISO-8859
# Solución recomendada
data=pd.read_csv('D:/dirty data/unclean_data1.csv', encoding='utf8') #Traemos el utf8 del archivo, funcionará perfectamente
#Mostrar los primeros 5 registros
data.head(5)
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# ### Nombres de Columnas Inconsistentes
# - Cambiar casos
# - Renombrarlas

# %% [markdown]
# ##### CAMBIAR EL NOMBRE DE LAS COLUMNAS A MAYÚSCULAS (UPPER)

# %%
#Mostramos las columnas de la data
data.columns
#Podemos observar que los nombres de las columnas no están alineados correctamente
#Hay columnas que están en Mayúsculas y otras en Minúsculas
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
#Observamos el cambio que se haría al poner las columnas en MAYÚSCULAS
data.columns.str.upper() 

#Para mínuscula sería: data.columns.str.lower()
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
#Modificamos el nombre de las columnas a MAYÚSCULAS
data.columns=data.columns.str.upper()

# %%
#Verificamos el cambio a MAYÚSCULAS de los nombres de las columnas
data.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %% [markdown]
# ##### RENOMBRAR COLUMNAS

# %%
#Para cambiar el nombre de la columna:
data.rename(columns={'DURATION':'TIME'}) #Cambiamos el nombre de la columnas "DURATION" por la de "TIME"
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# ### Datos Perdidos
#
# - Agregue un valor predeterminado para los datos faltantes o use la media para completarlo <br>
# - Eliminar la fila/columna con datos faltantes <br>
# - Interpolar las filas <br>
# - Reemplazar<br>
#
# ### Para comprobar si faltan datos

# %%
#Comprabar si hay datos NULL por REGISTRO - TRUE es porque lo hay
data.isnull()
# Out:
#     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  DURATION  DIRECTOR_FACEBOOK_LIKES  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
# Comprobar si hay datos NULL por COLUMNA#
data.isnull().any()
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS       False
# DURATION                      True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES       False
# ACTOR_1_FACEBOOK_LIKES       False
# GROSS                        False
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS         False
# BUDGET                       False
# TITLE_YEAR                   False
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                   False
# TITLE_YEAR.1                  True
# dtype: bool

# %%
# Comprobar si hay datos NULL en toda la DATA
data.isnull().any().any()
# True: podemos comprobar que hay datos faltantes o NULL
# Out:
# True

# %%
# Cantidad de valores NULL por cada COLUMNA
data.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# DURATION                     3
# DIRECTOR_FACEBOOK_LIKES      2
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              1
# CAST_TOTAL_FACEBOOK_LIKES    2
# FACENUMBER_IN_POSTER         5
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       1
# IMDB_SCORE                   0
# TITLE_YEAR.1                 7
# dtype: int64

# %%
# Cantidad de valores NULL por toda la DATA
data.isnull().sum().sum()
# Out:
# 21

# %% [markdown]
# ### Agregar un valor predeterminado o completar los datos que faltan

# %%
#Cambiar por un valor predeterminado a los valores null
df_with_0=data.fillna(0) #Guardamos en una variable la data con los valores NULL reemplazados por 0.

# %%
#Mostramos la data
df_with_0.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       0.0                     563                    1000
# 2     148.0                      20                     161
# 3       0.0                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
# LA MEJOR MANERA DE LLENAR LOS VALORES NULL, ES CON UNA MEDIDA

# Llenarlo con la media(mean), en la columna con valores NULL
data['DURATION'].mean() #verificamos la media
# Out:
# 150.72727272727272

# %%
#Llenamos los valores NULL con la media(mean) en la columna DURATION
data_with_mean=data.DURATION.fillna(data['DURATION'].mean())

# %%
#Verificamos los valores
data_with_mean
# Out:
# 0     178.000000
# 1     150.727273
# 2     148.000000
# 3     150.727273
# 4     132.000000
# 5     156.000000
# 6     150.727273
# 7     141.000000
# 8     141.000000
# 9     153.000000
# 10    183.000000
# 11    169.000000
# 12    106.000000
# 13    151.000000
# Name: DURATION, dtype: float64

# %% [markdown]
# ### Droping NA - Eliminar NULL

# %%
#Mostramos la cantidad total de NULL en la data
data.isnull().sum().sum() #21
# Out:
# 21

# %%
#Dimensionalidad de la data
data.shape #14 filas y 16 columnas
# Out:
# (14, 16)

# %%
#Eliminamos las filas con al menos un valor NULL (Default)
data_drop=data.dropna()

# %%
#Podemos observar que eliminó todos las filas con al menos un NULL
data_drop
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
#Eliminar las columnas con al menos un valor NULL
data_dop_col=data.dropna(axis='columns')

# %%
#Podemos observar que eliminó las columnas con al menos un null
data_dop_col
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
#Eliminar las filas donde todos sus valores son NULL
data_drop_how=data.dropna(how='all')

# %%
#Podemos observar que no se eliminó ningún registros, por el hecho de que ninguna fila tiene todos sus valores NULL
data_drop_how.shape
# Out:
# (14, 16)

# %%
#Mantener las filas con al menos 2 valores que no sean NULL
data_drop=data.dropna(thresh=2)

# %%
#Podemos verificar que no se eliminó ninguna fila, por el hecho que no cumple la condición
data_drop.shape
# Out:
# (14, 16)

# %%
#Definir en qué columnas buscar valores NULL - eliminar
data_drop_search_col=data.dropna(subset=['DIRECTOR_FACEBOOK_LIKES', 'DURATION'])

# %%
data_drop_search_col
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar?ÿ                     723
# 2                                      Spectre?ÿ                     602
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0      178.0                      10                     855
# 2      148.0                      20                     161
# ...

# %% [markdown]
# ### Dropping Duplicates - Eliminar duplicados
#
# - drop_duplicates() <br>
# - keep='first' <br>

# %%
#Verificar si hay duplicados (coincidencia en todos los valores)
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
#Especificar si hay valores duplicados por una columna en específico
data.duplicated('MOVIE_TITLE') #Duplicados con el mismo titulo de película
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
#Eliminamos los duplicados en la columna 'MOVIE_TITLE'
data_drop_dup=data.drop_duplicates('MOVIE_TITLE')

# %%
#Verificamos si hay duplicados por MOVIE_TITLE
data_drop_dup.duplicated('MOVIE_TITLE')
#Ya no existe duplicados
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %% [markdown]
# ### Tipos de datos Inconsistencias
#
# - Cambiar el tipo de datos después de leer el csv <br>
# - Cambie el tipo de datos antes de leer csv ++ pd.read_csv(url, dtype={'column1':float})

# %%
df = pd.read_csv('file.csv', dtype={'column1':float})

# %%
#Ver el tipo de dato
df.dtypes

# %%
#Cambiar el tipo de dato a uno correcto
df.GROSS.astype(float).dtypes
